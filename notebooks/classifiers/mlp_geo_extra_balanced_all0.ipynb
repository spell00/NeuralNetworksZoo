# %%
import os
os.chdir("../../")

# %% [markdown]
# https://stats.stackexchange.com/questions/321841/what-are-variational-autoencoders-and-to-what-learning-tasks-are-they-used
#
# Ideal parameters:
# $$ \min_{\boldsymbol{\lambda}}\mathcal{D}[p(\mathbf{z}\vert \mathbf{x})\vert\vert q(\mathbf{z}\vert \mathbf{x},\boldsymbol{\lambda})] $$
#
# It should also minimize the reconstruction loss (and optional regularization terms, mainly L1 or L2)
#
# VAE loss function:
# $$ELBO(\boldsymbol{\lambda})= E_{q(\boldsymbol{z}\vert \mathbf{x},\boldsymbol{\lambda})}[\log p(\mathbf{x}\vert\boldsymbol{z})]-\mathcal{D}[(q(\boldsymbol{z}\vert \mathbf{x},\boldsymbol{\lambda})\vert\vert p(\boldsymbol{z})]$$
#
# $$ q(\mathbf{z}\vert \mathbf{x},\boldsymbol{\lambda}) = \mathcal{N}(\mathbf{z}\vert\boldsymbol{\mu}(\mathbf{x}), \boldsymbol{\sigma}^2(\mathbf{x})I) $$
#
# conditional distribution:
# $$ p_{\boldsymbol{\phi}}(\mathbf{x}\vert\mathbf{z}) = \mathcal{N}(\mathbf{x}|\boldsymbol{\mu}(\mathbf{z}; \boldsymbol{\phi}), \boldsymbol{\sigma}(\mathbf{z}; \boldsymbol{\phi})^2I)$$

# %% [markdown]
# $$ ELBO(\boldsymbol{\theta},\boldsymbol{\phi})= \sum_i E_{q_{\boldsymbol{\theta}}(\boldsymbol{z}\vert \mathbf{x}_i,\boldsymbol{\lambda})}[\log p_{\boldsymbol{\phi}}(\mathbf{x}_i\vert\boldsymbol{z})]-\mathcal{D}[(q_{\boldsymbol{\theta}}(\boldsymbol{z}\vert \mathbf{x}_i,\boldsymbol{\lambda})\vert\vert p(\boldsymbol{z})] $$

# %%
# Import packages
from data_preparation.GeoParser import GeoParser
from dimension_reduction.ordination import ordination2d
from sklearn.decomposition import PCA
from IPython.display import Image
import pandas as pd
import numpy as np

# %% [markdown]
# Import models

# %%
from models.discriminative.artificial_neural_networks.hebbian_network.HebbNet import HebbNet
from models.discriminative.artificial_neural_networks.MultiLayerPerceptron import MLP
from utils.utils import dict_of_int_highest_elements, plot_evaluation
# Out:
# Using TensorFlow backend.

# %%
geo_ids = ["GSE33000"]
# files_destinations
home_path = "/home/simon/"
destination_folder = "annleukemia"
data_folder = "data"
results_folder = "results"
meta_destination_folder = "pandas_meta_df"
load_from_disk = False
load_merge = False

plots_folder_path = "/".join([home_path, destination_folder, results_folder, "plots/"])

# %%
#dataset_name = "gse33000_and_GSE24335_GSE44768_GSE44771_GSE44770"
dataset_name = "gse33000+4"
activation = "relu"
#nrep = 3
early_stopping = 200
n_epochs = 1000
gt_input = 0
extra_class=True
# if ladder is yes builds a ladder vae. Do not combine with auxiliary (yet; might be possible and relatively 
# not too hard to implement, but might be overkill. Might be interesting too)
translate = "n"

# %%
# Types of deep generative model

# Convolution neural network (convolutional VAE and convolutional classifier)
use_conv = False #Not applicable if not sequence (images, videos, sentences, DNA...)

# %% [markdown]
# Definition of the hyper-parameters

# %%
lr = 1e-5
l1 = 1e-8
l2 = 1e-8
batch_size = 32
#mc = 1 
#iw = 1 

# Neurons layers
h_dims = [1024, 128]

# %%
from utils.utils import adapt_datasets
g = GeoParser(home_path=home_path, geo_ids=geo_ids)
g.get_geo(load_from_disk=load_from_disk, automatic_attribute_list=None)
meta_df = g.merge_datasets(load_from_disk=load_merge, labelled=True)
if translate is "y":
    for geo_id in geo_ids:
        g.translate_indices_df(geo_id, labelled=True)
# Out:
# 14-Nov-2018 19:24:57 DEBUG utils - Directory /home/simon//annleukemia/data//softs/ already exists. Skipping.
# 14-Nov-2018 19:24:57 INFO GEOparse - File already exist: using local version.
# 14-Nov-2018 19:24:57 INFO GEOparse - Parsing /home/simon//annleukemia/data//softs/GSE33000_family.soft.gz:
# 14-Nov-2018 19:24:57 DEBUG GEOparse - DATABASE: GeoMiame
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SERIES: GSE33000
# 14-Nov-2018 19:24:57 DEBUG GEOparse - PLATFORM: GPL4372
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423780
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423781
# Running: GSE33000
# Building the dataset ...
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423782
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423783
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423784
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423785
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423786
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423787
# 14-Nov-2018 19:24:57 DEBUG GEOparse - SAMPLE: GSM1423788
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423789
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423790
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423791
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423792
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423793
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423794
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423795
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423796
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423797
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423798
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423799
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423800
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423801
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423802
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423803
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423804
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423805
# 14-Nov-2018 19:24:58 DEBUG GEOparse - SAMPLE: GSM1423806
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423807
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423808
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423809
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423810
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423811
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423812
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423813
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423814
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423815
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423816
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423817
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423818
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423819
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423820
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423821
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423822
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423823
# 14-Nov-2018 19:24:59 DEBUG GEOparse - SAMPLE: GSM1423824
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423825
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423826
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423827
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423828
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423829
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423830
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423831
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423832
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423833
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423834
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423835
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423836
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423837
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423838
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423839
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423840
# 14-Nov-2018 19:25:00 DEBUG GEOparse - SAMPLE: GSM1423841
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423842
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423843
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423844
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423845
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423846
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423847
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423848
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423849
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423850
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423851
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423852
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423853
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423854
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423855
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423856
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423857
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423858
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423859
# 14-Nov-2018 19:25:01 DEBUG GEOparse - SAMPLE: GSM1423860
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423861
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423862
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423863
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423864
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423865
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423866
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423867
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423868
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423869
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423870
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423871
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423872
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423873
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423874
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423875
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423876
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423877
# 14-Nov-2018 19:25:02 DEBUG GEOparse - SAMPLE: GSM1423878
# 14-Nov-2018 19:25:03 DEBUG GEOparse - SAMPLE: GSM1
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424374
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424375
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424376
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424377
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424378
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424379
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424380
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424381
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424382
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424383
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424384
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424385
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424386
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424387
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424388
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424389
# 14-Nov-2018 19:25:30 DEBUG GEOparse - SAMPLE: GSM1424390
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424391
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424392
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424393
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424394
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424395
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424396
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424397
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424398
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424399
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424400
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424401
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424402
# 14-Nov-2018 19:25:31 DEBUG GEOparse - SAMPLE: GSM1424403
# 2 Choices are available for GSM
# 7 Choices are available for GPL. You must select:
# 1 - An annotation for GPL
# 2 - (optional) The annotation you want the row names to take
# According to which of the following attributes will be the samples group
# 0 - ID
# 1 - EntrezGeneID
# 2 - ORF
# 3 - GB_ACC
# 4 - PROBE_DERIVED_FROM_TRANSCRIPT
# 5 - SPOT_ID
# 6 - RosettaGeneModelID
# Select a number [0-6]3
# 0 - title58974359 %%%
#      PFC_1
# 1 - geo_accession
#      GSM1423780
# 2 - status
#      Public on Jul 31 2014
# 3 - submission_date
#      Jul 01 2014
# 4 - last_update_date
#      Jul 31 2014
# 5 - type
#      RNA
# 6 - channel_count
#      2
# 7 - source_name_ch1
#      HBTRC_PF_Pool_1
# 8 - organism_ch1
#      Homo sapiens
# 9 - taxid_ch1
#      9606
# 10 - characteristics_ch1
#      tissue: prefrontal cortex brain sample type: reference
# 11 - treatment_protocol_ch1
#      NA
# 12 - growth_protocol_ch1
#      Fresh-frozen post-mortem brain tissues.
# 13 - molecule_ch1
#      total RNA
# 14 - extract_protocol_ch1
#      Qiagen RNeasy spin columns with DNase treatment.
# 15 - label_ch1
#      Cy3
# 16 - label_protocol_ch1
#      Samples were amplified and labeled using a custom automated two-cycle version of the MessageAmp II kit from Ambion. Sample amplification, labeling, and microarray processing were performed by the Rosetta Inpharmatics Gene Expression Laboratory in Seattle, Wash.
# 17 - source_name_ch2
#      PFC_1
# 18 - organism_ch2
#      Homo sapiens
# 19 - taxid_ch2
#      9606
# 20 - characteristics_ch2
#      tissue: prefrontal cortex brain age: 67 yrs gender: female disease status: Alzheimer's disease
# 21 - treatment_protocol_ch2
#      NA
# 22 - growth_protocol_ch2
#      Fresh-frozen post-mortem brain tissues.
# 23 - molecule_ch2
#      total RNA
# 24 - extract_protocol_ch2
#      Qiagen RNeasy spin columns with DNase treatment.
# 25 - label_ch2
#      Cy5
# 26 - label_protocol_ch2
#      Samples were amplified and labeled using a custom automated two-cycle version of the MessageAmp II kit from Ambion. Sample amplification, labeling, and microarray processing were performed by the Rosetta Inpharmatics Gene Expression Laboratory in Seattle, Wash.
# 27 - hyb_protocol
#      Microarrays were incubated at 40C for 48 hours in a rotating carousel. Hybridizations to custom Agilent microarrays were completed as previously described (Hughes et al. Nat Biotech (2001), 19(4):342-7). Microarrays were washed to remove non-specific hybridized sample. Afterwards, microarrays were dried in an ozone-free nitrogen chamber.
# 28 - scan_protocol
#      Microarrays were scanned using the Agilent LP2 laser scanner. The scanner output is a Tiff file, which contains the quantitative hybridization data from each individual microarray. The Tiff files were then processed using Rosetta custom feature extraction software.
# 29 - description
#      Dorsolateral prefrontal cortex (DLPFC)
# 30 - data_processing
#      Data were processed using the Rosetta Resolver system. Rosetta's custom feature extraction software performs error modeling before data are loaded into the Resolver system. The Resolver system performs a squeeze operation that combines replicates of the same sequence in an array while applying error weighting. The error weighting consists of adjusting for additive and multiplicative noise. A P-value is generated and propagated throughout the system. The P-value represents the probability that a gene is expressed. The Resolver system allows users to set thresholds, below which genes of a P-value are considered to be significantly expressed. The Resolver system also combines multiple arrays using a squeezing process. If multiple spots reference one sequence, summarization is performed using an error-weighted average as described in Roland Stoughton and Hongyue Dai, Statistical Combining of Cell Expression Profiles. US Patent #6,351,712, February 26, 2002.
# 31 - platform_id
#      GPL4372
# 32 - contact_name
#      Jun,,Zhu
# 33 - contact_email
#      junzhu_99@yahoo.com
# 34 - contact_department
#      Genetics and Genomic Sciences
# 35 - contact_institute
#      Icahn Medical School at Mount Sinai
# 36 - contact_address
#      One Gustave L Levy, Box 1498
# 37 - contact_city
#      New York
# 38 - contact_state
#      NY
# 39 - contact_zip/postal_code
#      10029
# 40 - contact_country
#      USA
# 41 - supplementary_file
#      NONE
# 42 - series_id
#      GSE33000
# 43 - data_row_count
#      39280
# Do you want to rename any of the metadata values? (input a number if yes or nothing if no)
# Enter a number:20
# How many samples names you want to see?3
# tissue: prefrontal cortex brain age: 67 yrs gender: female disease status: Alzheimer's disease
# tissue: prefrontal cortex brain age: 88 yrs gender: male disease status: Alzheimer's disease
# tissue: prefrontal cortex brain age: 62 yrs gender: male disease status: Alzheimer's disease
# Do you want to rename the labels?
# [y/n]y
# Type the characters for split?:
# 0 - tissue
# 1 -  prefrontal cortex brain age
# 2 -  67 yrs gender
# 3 -  female disease status
# 4 -  Alzheimer's disease
# (ex: 1:3;5-8;10 to select from 1 to 3 and 5 to 8 and 10)
# [0-4]; enter n to not rename)4
# Do you want to apply these selections to all of the next samples?
# [y/n]y
# Rename other metadata? [y/n]n
# According to which of the following attributes will be the samples group
# 0 - status
#      Public on Jul 31 2014
# 1 - submission_date
#      Jul 01 2014
# 2 - last_update_date
#      Jul 31 2014
# 3 - type
#      RNA
# 4 - channel_count
#      2
# 5 - organism_ch1
#      Homo sapiens
# 6 - taxid_ch1
#      9606
# 7 - characteristics_ch1
#      tissue: prefrontal cortex brain sample type: reference
# 8 - treatment_protocol_ch1
#      NA
# 9 - growth_protocol_ch1
#      Fresh-frozen post-mortem brain tissues.
# 10 - molecule_ch1
#      total RNA
# 11 - extract_protocol_ch1
#      Qiagen RNeasy spin columns with DNase treatment.
# 12 - label_ch1
#      Cy3
# 13 - label_protocol_ch1
#      Samples were amplified and labeled using a custom automated two-cycle version of the MessageAmp II kit from Ambion. Sample amplification, labeling, and microarray processing were performed by the Rosetta Inpharmatics Gene Expression Laboratory in Seattle, Wash.
# 14 - organism_ch2
#      Homo sapiens
# 15 - taxid_ch2
#      9606
# 16 - characteristics_ch2
#        Alzheimer's disease
# 17 - treatment_protocol_ch2
#      NA
# 18 - growth_protocol_ch2
#      Fresh-frozen post-mortem brain tissues.
# 19 - molecule_ch2
#      total RNA
# 20 - extract_protocol_ch2
#      Qiagen RNeasy spin columns with DNase treatment.
# 21 - label_ch2
#      Cy5
# 22 - label_protocol_ch2
#      Samples were amplified and labeled using a custom automated two-cycle version of the MessageAmp II kit from Ambion. Sample amplification, labeling, and microarray processing were performed by the Rosetta Inpharmatics Gene Expression Laboratory in Seattle, Wash.
# 23 - hyb_protocol
#      Microarrays were incubated at 40C for 48 hours in a rotating carousel. Hybridizations to custom Agilent microarrays were completed as previously described (Hughes et al. Nat Biotech (2001), 19(4):342-7). Microarrays were washed to remove non-specific hybridized sample. Afterwards, microarrays were dried in an ozone-free nitrogen chamber.
# 24 - scan_protocol
#      Microarrays were scanned using the Agilent LP2 laser scanner. The scanner output is a Tiff file, which contains the quantitative hybridization data from each individual microarray. The Tiff files were then processed using Rosetta custom feature extraction software.
# 25 - description
#      Dorsolateral prefrontal cortex (DLPFC)
# 26 - data_processing
#      Data were processed using the Rosetta Resolver system. Rosetta's custom feature extraction software performs error modeling before data are loaded into the Resolver system. The Resolver system performs a squeeze operation that combines replicates of the same sequence in an array while applying error weighting. The error weighting consists of adjusting for additive and multiplicative noise. A P-value is generated and propagated throughout the system. The P-value represents the probability that a gene is expressed. The Resolver system allows users to set thresholds, below which genes of a P-value are considered to be significantly expressed. The Resolver system also combines multiple arrays using a squeezing process. If multiple spots reference one sequence, summarization is performed using an error-weighted average as described in Roland Stoughton and Hongyue Dai, Statistical Combining of Cell Expression Profiles. US Patent #6,351,712, February 26, 2002.
# 27 - platform_id
#      GPL4372
# 28 - contact_name
#      Jun,,Zhu
# 29 - contact_email
#      junzhu_99@yahoo.com
# 30 - contact_department
#      Genetics and Genomic Sciences
# 31 - contact_institute
#      Icahn Medical School at Mount Sinai
# 32 - contact_address
#      One Gustave L Levy, Box 1498
# 33 - contact_city
#      New York
# 34 - contact_state
#      NY
# 35 - contact_zip/postal_code
#      10029
# 36 - contact_country
#      USA
# 37 - supplementary_file
#      NONE
# 38 - series_id
#      GSE33000
# 39 - data_row_count
#      39280
# Select a number [0-39]16
# How many samples names you want to see?6
#   Alzheimer's disease
#   Alzheimer's disease
#   Alzheimer's disease
#   Alzheimer's disease
#   Alzheimer's disease
#   Alzheimer's disease
# Are you satisfied with your seletection? (y/n)y
# Do you want to rename the labels?
# [y/n]n
# Type the characters for split?
# Give new labels set names manually?
# Saving to /home/simon//annleukemia/data//dataframes//GSE33000_labelledTrue_dataframe
# The file containing the data for  GSE33000  was loaded successfully!
# Preparing for merging the selected datasets... labelled: True
# The file you were looking for is there
# File found!
# merging file: 1 / 1
# (35371, 624)
# Saving files...
# Merged sets loaded.

# %%
# TODO CHANGE hard coded input size, should be easy to get from get_geo
labels = set(list(meta_df.columns))
mlp = MLP(input_size=meta_df.shape[0], input_shape=(meta_df.shape[0]), 
          indices_names=list(range(meta_df.shape[0])), num_classes=len(labels), 
          h_dims=h_dims, extra_class=extra_class, l1=l1, l2=l2, batch_norm=True)

mlp.set_configs(home_path=home_path, results_folder=results_folder, data_folder=data_folder,
                    destination_folder=destination_folder, dataset_name=dataset_name, lr=lr,
                    meta_destination_folder="meta_pandas_dataframes", csv_filename="csv_loggers", is_unlabelled=False)
# Out:
# self.input_size 35371

# %%
print("Labeled data shape (35371, 624)", meta_df.shape)
if meta_df is not None:
    mlp.import_dataframe(meta_df, batch_size, labelled=True)
# Out:
# Labeled data shape (35371, 624) (35371, 624)

# %%
ordination2d(meta_df, epoch="pre", dataset_name=dataset_name, ord_type="pca",
             images_folder_path=plots_folder_path)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
subset = meta_df[0:1000]

# %%
#tSNE
#ordination2d(subset, epoch="pre", dataset_name=dataset_name, ord_type="tsne", images_folder_path=plots_folder_path)

# %%
#mlp.define_configurations(early_stopping=early_stopping, warmup=warmup, flavour=vae_flavour)
print("train data shape", meta_df.shape)
# Out:
# train data shape (35371, 624)

# %%
# dgm.vae.generate_random(False, batch_size, z1_size, [1, 28, 28])

train_total_loss_histories = [[] for x in range(10)]
train_accuracy_histories = [[] for x in range(10)]
valid_total_loss_histories = [[] for x in range(10)]
valid_accuracy_histories = [[] for x in range(10)]
for i in range(100):
    print("Random train/valid split", i)
    mlp.set_data(labels_per_class=-1, is_example=False, extra_class=extra_class, ignore_training_inputs=3)
    mlp.glorot_init()
    mlp.run(n_epochs, verbose=0, show_progress=10, hist_epoch=20, is_balanced_relu=True, all0=True, 
           overall_mean=True)
# Out:
# Random train/valid split 0
# 499 train samples
# 62 valid samples
# 63 valid samples
# 624 total samples
# No unlabelled data
# self.train_loader 16
# self.train_loader 32
# self.train_loader <torch.utils.data.sampler.RandomSampler object at 0x7fb166a4e588>
# Log file created:  logs/MLP_parameters.log
# Log file created:  logs/MLP_involvment.log
# Log file created:  logs/MLP.log
# Labeled shape 16
# /home/simon/annleukemia/utils/plots.py:16: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
#   ax.plot(x, mlab.normpdf(x, mu, sigma))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-81aa070856fe> in <module>
#      10     mlp.glorot_init()
#      11     mlp.run(n_epochs, verbose=0, show_progress=10, hist_epoch=20, is_balanced_relu=True, all0=True,
# ---> 12            overall_mean=True)
#      13
#      14
#
# ~/annleukemia/models/discriminative/artificial_neural_networks/MultiLayerPerceptron.py in run(self, n_epochs, verbose, clip_grad, is_input_pruning, start_pruning, show_progress, is_balanced_relu, plot_progress, hist_epoch, all0, overall_mean)
#     340             total_loss, accuracy, accuracy_total = (0, 0, 0)
#     341
# --> 342             for x, y in self.valid_loader:
#     343
#     344                 c += len(x)
#
# ~/anaconda3/envs/annleukemia/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/annleukemia/lib/python3.6/site-packages/torch/utils/data/dataloader.py in default_collate(batch)
#     185     elif isinstance(batch[0], collections.Sequence):
#     186         transposed = zip(*batch)
# --> 187         return [default_collate(samples) for samples in transposed]
#     188
#     189     raise TypeError((error_msg.format(type(batch[0]))))
#
# ~/anaconda3/envs/annleukemia/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     185     elif isinstance(batch[0], collections.Sequence):
#     186         transposed = zip(*batch)
# --> 187         return [default_collate(samples) for samples in transposed]
#     188
#     189     raise TypeError((error_msg.format(type(batch[0]))))
#
# ~/anaconda3/envs/annleukemia/lib/python3.6/site-packages/torch/utils/data/dataloader.py in default_collate(batch)
#     162             storage = batch[0].storage()._new_shared(numel)
#     163             out = batch[0].new(storage)
# --> 164         return torch.stack(batch, 0, out=out)
#     165     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#     166             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %% [markdown]
# References
# Auto-Encoding Variational Bayes https://arxiv.org/abs/1312.6114
# Semi-Supervised Learning with Deep Generative Models https://arxiv.org/abs/1406.5298
# Ladder Variational Autoencoders https://arxiv.org/abs/1602.02282
# Auxiliary Deep Generative Models    https://arxiv.org/abs/1602.05473
# Sylvester Normalizing Flows for Variational Inference  https://arxiv.org/abs/1803.05649
# Improving Variational Auto-Encoders using Householder Flow https://arxiv.org/abs/1611.09630
# Variational Inference with Normalizing Flows https://arxiv.org/abs/1505.05770
# Convex combination linear IAF and the Householder Flow, J.M. Tomczak & M. Welling https://jmtomczak.github.io/deebmed.html

# %% [markdown]
# Github Ressources:
#     https://github.com/wohlert/semi-supervised-pytorch
#     https://github.com/jmtomczak/vae_vpflows
#     https://github.com/jmtomczak/vae_householder_flow

# %% [raw]
# TO DO:
#     Calculate negative log-likelihood (to be maximized)
#     Get ordinations for all_samples AND generated samples in the SAME plot;
#         (make them the same color, but only the genwerated with a black contour,
#         or the opposite, or different contours)
#     Add Inverse Autoregressive Flow for variational inference (IAF; very common and apparently good;
#         the base for other flavours, such as sylvester flows (to be verified))
